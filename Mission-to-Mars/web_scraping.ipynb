# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://nashville.craigslist.org/search/sss​'

# %%
response = requests.get(url)

# %%
response.text
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>nashville for sale  - craigslist</title>\n\n    <meta name="description" content="nashville for sale  - craigslist">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <link rel="canonical" href="https://nashville.craigslist.org/search/sss">\n    <link rel="alternate" type="application/rss+xml" href="https://nashville.craigslist.org/search/sss?format=rss" title="RSS feed for craigslist | nashville for sale  - craigslist">\n        <link rel="next" href="https://nashville.craigslist.org/search/sss?s=120">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=5826de27c327d61d2169c6a45af814f9">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b">\n    <link type="text/css" rel="stylesheet" media="all" href="//ww
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')
